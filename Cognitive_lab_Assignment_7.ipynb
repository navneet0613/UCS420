# %% [markdown]
# <a href="https://colab.research.google.com/github/navneet0613/UCS420/blob/main/Cognitive_lab_Assignment_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Q1. You are a data analyst at an e-commerce company. Your task is to analyze sales data,
# clean and process it, perform statistical analysis, and generate visual insights to help the
# business make informed decisions.
# 1. Use your roll number as the random seed to generate unique data for each student.
# 2. Follow the questions step by step, as each part builds upon the previous one.
# 3. Submit the assignment as a Jupyter Notebook (.ipynb) with:
#
# Well-documented code and clear comments.
# Markdown explanations for each step.
# Screenshots of the plots and outputs.
# Part I: Randomized Sales Data Generation (NumPy)
# 1. Initialize Random Seed
# 2. Generate Sales Data
#
# Create a NumPy array of random sales data for 12 months (shape = (12, 4)),
# where each column represents a product category:
# Electronics, Clothing, Home & Kitchen, Sports.
# Sales values should be between 1000 and 5000 units per month.
# The range should be randomized using the seed.
# 3. Convert to DataFrame
# Convert the cleaned NumPy array into a Pandas DataFrame with:
#
# i. Columns: Electronics, Clothing, Home & Kitchen, Sports
#
# ii. Index: Months from Jan to Dec
# Part II: Data Manipulation and Analysis (Pandas)
# 1. Display the first 5 rows and summary statistics of the DataFrame.
# 2. Calculate the total sales per category and total sales per month.
# 3. Calculate the average sales growth between consecutive months for each category.
# 4. Add the following columns to the DataFrame:
# Total Sales: Sum of all categories per month.
# Growth Rate: Percentage change in Total Sales from the previous month.
# 5. Apply a randomized discount:
# If your roll number is even, apply a 10% discount to the Electronics category.
# If odd, apply a 15% discount to the Clothing category.
#
# Part III: Visualizations (Matplotlib and Seaborn)
# 1. Plot monthly sales trends for each category using line plots.
# 2. Create the following plots:
#  Box plots to show the sales distribution for each category.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Part I: Randomized Sales Data Generation
roll_number = 102497009
np.random.seed(roll_number)
sales_data = np.random.randint(1000, 5000, size=(12, 4))
categories = ['Electronics', 'Clothing', 'Home & Kitchen', 'Sports']
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
df = pd.DataFrame(sales_data, columns=categories, index=months)

# Part II: Data Manipulation and Analysis
print('First 5 rows of the DataFrame:')
print(df.head())
print('\nSummary Statistics:')
print(df.describe())
total_sales_category = df.sum()
total_sales_month = df.sum(axis=1)
print('\nTotal Sales per Category:')
print(total_sales_category)
print('\nTotal Sales per Month:')
print(total_sales_month)
avg_growth = df.pct_change().mean() * 100
print('\nAverage Sales Growth per Category:')
print(avg_growth)
df['Total Sales'] = df.sum(axis=1)
df['Growth Rate'] = df['Total Sales'].pct_change() * 100

# Discount Application
if roll_number % 2 == 0:
    df['Electronics'] *= 0.9
else:
    df['Clothing'] *= 0.85

# Part III: Visualizations
plt.figure(figsize=(10, 6))
df[categories].plot(kind='line', marker='o')
plt.title('Monthly Sales Trends')
plt.xlabel('Month')
plt.ylabel('Sales Units')
plt.legend(title='Categories')
plt.grid(True)
plt.show()
sns.boxplot(data=df[categories])
plt.title('Sales Distribution by Category')
plt.show()
# Out:
# First 5 rows of the DataFrame:
#      Electronics  Clothing  Home & Kitchen  Sports
# Jan         1926      3094            4193    3614
# Feb         4178      3322            3592    1531
# Mar         2724      1341            2068    4689
# Apr         4787      4300            1726    3633
# May         3767      4408            1032    4332
#
# Summary Statistics:
#        Electronics     Clothing  Home & Kitchen       Sports
# count    12.000000    12.000000       12.000000    12.000000
# mean   3048.083333  3406.833333     3321.083333  2959.500000
# std    1268.752677  1035.635671     1209.169998  1025.261785
# min    1300.000000  1341.000000     1032.000000  1531.000000
# 25%    2187.750000  3028.750000     2390.500000  2065.500000
# 50%    2862.500000  3340.500000     3857.500000  2973.500000
# 75%    4197.000000  4327.000000     4245.250000  3618.750000
# max    4787.000000  4855.000000     4546.000000  4689.000000
#
# Total Sales per Category:
# Electronics       36577
# Clothing          40882
# Home & Kitchen    39853
# Sports            35514
# dtype: int64
#
# Total Sales per Month:
# Jan    12827
# Feb    12623
# Mar    10822
# Apr    14446
# May    13539
# Jun    10513
# Jul    16268
# Aug    13496
# Sep    14063
# Oct    12059
# Nov    10286
# Dec    11884
# dtype: int64
#
# Average Sales Growth per Category:
# Electronics       29.860417
# Clothing          19.855281
# Home & Kitchen    14.566025
# Sports            16.061665
# dtype: float64

# %% [markdown]
# Q.2 For the array: array = np.array([[1, -2, 3],[-4, 5, -6]])
#
# i. Find element-wise absolute value
#
# ii. Find the 25th, 50th, and 75th percentile of flattened array, for each column, for each
# row.
#
# iii. Mean, Median and Standard Deviation of flattened array, of each column, and
# each row

# %%
import numpy as np

# Given Array
array = np.array([[1, -2, 3], [-4, 5, -6]])

# i. Element-wise Absolute Value
print("Absolute Value:\n", np.abs(array))

# Flattened Array
flat = array.flatten()

# ii. Percentiles
print("\nPercentiles (Flattened):", np.percentile(flat, [25, 50, 75]))
print("Percentiles (Columns):\n", np.percentile(array, [25, 50, 75], axis=0))
print("Percentiles (Rows):\n", np.percentile(array, [25, 50, 75], axis=1))

# iii. Mean, Median, Std Dev
print("\nMean, Median, Std Dev (Flattened):", np.mean(flat), np.median(flat), np.std(flat))
print("Mean, Median, Std Dev (Columns):\n", np.mean(array, axis=0), np.median(array, axis=0), np.std(array, axis=0))
print("Mean, Median, Std Dev (Rows):\n", np.mean(array, axis=1), np.median(array, axis=1), np.std(array, axis=1))
# Out:
# Absolute Value:
#  [[1 2 3]
#  [4 5 6]]
#
# Percentiles (Flattened): [-3.5 -0.5  2.5]
# Percentiles (Columns):
#  [[-2.75 -0.25 -3.75]
#  [-1.5   1.5  -1.5 ]
#  [-0.25  3.25  0.75]]
# Percentiles (Rows):
#  [[-0.5 -5. ]
#  [ 1.  -4. ]
#  [ 2.   0.5]]
#
# Mean, Median, Std Dev (Flattened): -0.5 -0.5 3.8622100754188224
# Mean, Median, Std Dev (Columns):
#  [-1.5  1.5 -1.5] [-1.5  1.5 -1.5] [2.5 3.5 4.5]
# Mean, Median, Std Dev (Rows):
#  [ 0.66666667 -1.66666667] [ 1. -4.] [2.05480467 4.78423336]

# %% [markdown]
# Q.3 For the array: a = np.array([-1.8, -1.6, -0.5, 0.5,1.6, 1.8, 3.0]).
#
#  Find floor, ceiling and truncated value, rounded values

# %%
a = np.array([-1.8, -1.6, -0.5, 0.5, 1.6, 1.8, 3.0])
print('Floor:',np.floor(a))
print('\nCeiling:',np.ceil(a))
print('\nTruncated:',np.trunc(a))
print('\nRounded:',np.round(a))
# Out:
# Floor: [-2. -2. -1.  0.  1.  1.  3.]
#
# Ceiling: [-1. -1. -0.  1.  2.  2.  3.]
#
# Truncated: [-1. -1. -0.  0.  1.  1.  3.]
#
# Rounded: [-2. -2. -0.  0.  2.  2.  3.]

# %% [markdown]
# Q.4 WAP to swap two elements in a list in Python Using a Temporary Variable.

# %%
list1 = [1, 2, 3, 4, 5]
temp = list1[1]
list1[1] = list1[3]
list1[3] = temp
print('\nSwapped List:', list1)
# Out:
# Swapped List: [1, 4, 3, 2, 5]

# %% [markdown]
# Q.5 Write a Python program to swap two elements in a set by converting it to a list first.

# %%
n = {34,67,54,65}
n = list(n)
n[0], n[2] = n[2], n[0]
n = set(n)
print('\nSwapped Set:', n)
# Out:
# Swapped Set: {65, 34, 67, 54}
